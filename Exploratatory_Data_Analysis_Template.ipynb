# %% [markdown]
# # Exploratory Data Analysis (EDA)
# #### https://www.analyticsvidhya.com/blog/2021/05/exploratory-data-analysis-eda-a-step-by-step-guide/

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Reading data

# %%
# Load the RAW_2019-2020 NSCH_Topical_CAHMI_DRC.csv dataset.
file_path = ('C:/Users/tligh/Desktop/Sensory_Needs_Occupational_Therapy/Data/2019-2020 NSCH_Topical_CAHMI_DRC_Original.csv')
Original_NCSH_df = pd.read_csv(file_path)
Original_NCSH_df.head(10)
# Out:
#    FIPSST  STRATUM      HHID  FORMTYPE  TOTKIDS_R  TENURE  HHLANGUAGE  \
# 0       1        1  19000167         3          2       3           1
# 1       1        1  19001238         1          4       1           1
# 2       1        1  19001344         3          3       1           1
# 3       1        1  19001345         3          1       1           1
# 4       1        1  19001347         1          1       3           1
# 5       1        1  19001355         1          1       1           1
# 6       1        1  19001524         1          1       1           1
# 7       1        1  19001651         3          2       1           1
# 8       1        1  19001670         3          2       1           1
# 9       1        1  19001714         3          1       2           1
#
#    SC_AGE_YEARS  SC_SEX  K2Q35A_1_YEARS  ...  npm9bullied_1920  \
# 0            17       1              95  ...                 1
# 1             4       2              95  ...                90
# ...

# %% [markdown]
# K2Q35A Question: Has a doctor or other health care provider EVER told you that this child has… Autism or Autism Spectrum Disorder (ASD)? Include diagnoses of Asperger’’s Disorder or Pervasive Developmental Disorder (PDD).
#
# K2Q35B Question: If yes, does this child CURRENTLY have the condition? (variable name differs based on condition)

# %%
Autism_types_df = pd.DataFrame.columns(Original_NCSH_df)
Autism_types_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9468\2403416652.py in <module>
# ----> 1 Autism_types_df = pd.DataFrame.columns(Original_NCSH_df)
#       2 Autism_types_df.head()
#
# TypeError: 'pandas._libs.properties.AxisProperty' object is not callable

# %%
Autism_types_df = pd.DataFrame(Original_NCSH_df).columns ([(Original_NCSH_df)])
Autism_types_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9468\3651827802.py in <module>
# ----> 1 Autism_types_df = pd.DataFrame(Original_NCSH_df).columns ([(Original_NCSH_df)])
#       2 Autism_types_df.head()
#
# TypeError: 'Index' object is not callable

# %%
# Check to see if how Autims types compare, are they mutulaly exclusive?
df_cols = ['K2Q35A', 'month' , 'year', 'min_temp', 'max_temp']

Autism_type_df = Original_NCSH_df
Autism_type_df = pd.DataFrame(columns=['FIPSST'], values)
Autism_type_df.head()
# Out:
#   File "C:\Users\tligh\AppData\Local\Temp\ipykernel_9468\3892255584.py", line 5
#     Autism_type_df = pd.DataFrame(columns=['FIPSST'], values)
#                                                      ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ### Descriptive Statistics

# %%
Original_NCSH_df.describe(include='all')
# Out:
#              FIPSST       STRATUM          HHID      FORMTYPE     TOTKIDS_R  \
# count  72210.000000  72210.000000  7.221000e+04  72210.000000  72210.000000
# mean      29.328930      1.076347  1.970175e+07      2.130924      1.846503
# std       15.799924      0.265554  5.090231e+05      0.822470      0.865593
# min        1.000000      1.000000  1.900000e+07      1.000000      1.000000
# 25%       16.000000      1.000000  1.911378e+07      1.000000      1.000000
# 50%       30.000000      1.000000  2.003801e+07      2.000000      2.000000
# 75%       41.000000      1.000000  2.014001e+07      3.000000      2.000000
# max       56.000000      2.000000  2.024000e+07      3.000000      4.000000
#
#              TENURE    HHLANGUAGE  SC_AGE_YEARS        SC_SEX  K2Q35A_1_YEARS  \
# count  72210.000000  72210.000000  72210.000000  72210.000000    72210.000000
# mean       1.485985      1.500914      9.469035      1.481692       92.586913
# ...

# %% [markdown]
# ### Missing value imputation

# %%
Original_NCSH_df.isnull().sum()
# Out:
# FIPSST                     0
# STRATUM                    0
# HHID                       0
# FORMTYPE                   0
# TOTKIDS_R                  0
#                           ..
# npm12TransCSHCN_1920       0
# npm12TransNonCSHCN_1920    0
# npm13_2DePrev_1920         0
# npm14_2Smoke_1920          0
# npm15AdIns_1920            0
# Length: 820, dtype: int64

# %% [markdown]
# ## Graphical representation

# %% [markdown]
# ####  Univariate Analysis - Bar Chart

# %%
plt.subplot(221)

df['gender'].value_counts().plot(kind='bar', title='Gender of students', figsize=(16,9))

plt.xticks(rotation=0)

plt.subplot(222)

df['race/ethnicity'].value_counts().plot(kind='bar', title='Race/ethnicity of students')

plt.xticks(rotation=0)

plt.subplot(223)

df['lunch'].value_counts().plot(kind='bar', title='Lunch status of students')

plt.xticks(rotation=0)

plt.subplot(224)

df['test preparation course'].value_counts().plot(kind='bar', title='Test preparation course')

plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# ####  Univariate Analysis - Box Plot

# %% [markdown]
# ####  Univariate Analysis - Distribution Plot

# %% [markdown]
# ####  Univariate Analysis: Coorelation - Heatmap

# %% [markdown]
# #### Bivariate Analysis - Relational Plot

# %% [markdown]
# #### Bivariate Analysis -Line Plot

# %% [markdown]
# #### Bivariate Analysis -Horizontal Bar Graph
