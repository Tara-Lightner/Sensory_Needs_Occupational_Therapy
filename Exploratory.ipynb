# %%
import pandas as pd

# %%
file1 = "data/ADV_Cumulative_Incidence_Data.csv"
df1 = pd.read_csv(file1)
df1.head()
# Out:
#    Age  Months State  Cumulative Incidence  95% Confidence Interval, Lower  \
# 0    4       1    AZ                   0.0                   -2.709350e-17
# 1    4       2    AZ                   0.0                   -2.709350e-17
# 2    4       3    AZ                   0.0                   -2.709350e-17
# 3    4       4    AZ                   0.0                   -2.709350e-17
# 4    4       5    AZ                   0.0                   -2.709350e-17
#
#    95% Confidence Interval, Upper  Survey Year
# 0                        0.426789         2016
# 1                        0.426789         2016
# 2                        0.426789         2016
# 3                        0.426789         2016
# 4                        0.426789         2016

# %%
df1.count()
# Out:
# Age                               2856
# Months                            2856
# State                             2856
# Cumulative Incidence              2856
# 95% Confidence Interval, Lower    2856
# 95% Confidence Interval, Upper    2856
# Survey Year                       2856
# dtype: int64

# %%
df1.nunique()
# Out:
# Age                                  2
# Months                             108
# State                               18
# Cumulative Incidence              2123
# 95% Confidence Interval, Lower    2131
# 95% Confidence Interval, Upper    2162
# Survey Year                          2
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Age                               0
# Months                            0
# State                             0
# Cumulative Incidence              0
# 95% Confidence Interval, Lower    0
# 95% Confidence Interval, Upper    0
# Survey Year                       0
# dtype: int64

# %%
file2 = "data/ADV_ADDMN-National-Data.csv"
df2 = pd.read_csv(file2)
df2.head()
# Out:
#    year abbr  male_prev  male_ci_l  male_ci_u  female_prev  female_ci_l  \
# 0  2000   US        NaN        NaN        NaN          NaN          NaN
# 1  2002   US       11.5        NaN        NaN          2.7          NaN
# 2  2004   US       12.9       12.2       13.7          2.9          2.6
# 3  2006   US       14.5       13.9       15.1          3.2          2.9
# 4  2008   US       18.4       17.7       19.0          4.0          3.7
#
#    female_ci_u  white_prev  white_ci_l  ...  black_ci_u  hisp_prev  hisp_ci_l  \
# 0          NaN         NaN         NaN  ...         NaN        NaN        NaN
# 1          NaN         7.7         NaN  ...         NaN        NaN        NaN
# 2          3.3         9.7         9.1  ...         7.6        6.2        5.0
# 3          3.5         9.9         9.4  ...         7.8        5.9        5.3
# 4          4.3        12.0        11.5  ...        10.9        7.9        7.2
#
# ...

# %%
df2.count()
# Out:
# year           10
# abbr           10
# male_prev       9
# male_ci_l       8
# male_ci_u       8
# female_prev     9
# female_ci_l     8
# female_ci_u     8
# white_prev      9
# white_ci_l      8
# white_ci_u      8
# black_prev      9
# black_ci_l      8
# black_ci_u      8
# hisp_prev       8
# hisp_ci_l       8
# hisp_ci_u       8
# api_prev        6
# api_ci_l        6
# api_ci_u        6
# aian_prev       1
# aian_ci_l       1
# aian_ci_u       1
# dtype: int64

# %%
df2.nunique()
# Out:
# year           10
# abbr            1
# male_prev       9
# male_ci_l       8
# male_ci_u       8
# female_prev     9
# female_ci_l     8
# female_ci_u     8
# white_prev      9
# white_ci_l      8
# white_ci_u      7
# black_prev      9
# black_ci_l      8
# black_ci_u      8
# hisp_prev       8
# hisp_ci_l       8
# hisp_ci_u       8
# api_prev        6
# api_ci_l        6
# api_ci_u        6
# aian_prev       1
# aian_ci_l       1
# aian_ci_u       1
# dtype: int64

# %%
file3 = "data/ADV_ADDMN-State-Data.csv"
df3 = pd.read_csv(file3)
df3
# Out:
#      year abbr  male_prev  male_ci_l  male_ci_u  female_prev  female_ci_l  \
# 0    2000   AZ        9.7        8.5       11.1          3.2          2.5
# 1    2000   GA       11.0        9.7       12.4          2.0          1.5
# 2    2000   MD        8.6        7.1       10.6          2.2          1.5
# 3    2000   NJ       14.8       13.0       16.8          4.3          3.3
# 4    2000   SC        9.3        7.8       11.2          3.3          2.4
# ..    ...  ...        ...        ...        ...          ...          ...
# 103  2018   MO       25.0       22.4       27.9          7.6          6.2
# 104  2018   NJ       45.6       41.4       50.1         10.1          8.2
# 105  2018   TN       36.0       32.9       39.3          8.8          7.3
# 106  2018   UT       33.1       30.2       36.3          9.3          7.7
# 107  2018   WI       30.0       27.4       32.8          7.1          5.9
#
#      female_ci_u  white_prev  white_ci_l  ...  black_ci_u  hisp_prev  \
# ...

# %%
file4 = "data/ADV_ADDMN-Key.csv"
df4 = pd.read_csv(file4)
df4.head()
# Out:
#    white                Non-hispanic white
# 0  black                Non-hispanic black
# 1   hisp                          Hispanic
# 2    api         Asian or Pacific Islander
# 3   aian  American Indian or Alaska Native
# 4   prev                        Prevalence

# %%
df4.count()
# Out:
# white                 9
# Non-hispanic white    8
# dtype: int64

# %%
df4.head(9)
# Out:
#                                                white  \
# 0                                              black
# 1                                               hisp
# 2                                                api
# 3                                               aian
# 4                                               prev
# 5                                               ci.l
# 6                                               ci.u
# 7                                               abbr
# 8  Note: All data is from health and education re...
#
#                  Non-hispanic white
# 0                Non-hispanic black
# 1                          Hispanic
# 2         Asian or Pacific Islander
# 3  American Indian or Alaska Native
# 4                        Prevalence
# 5         Lower Confidence Interval
# 6         Upper Confidence Interval
# 7                State abbreviation
# 8                               NaN

# %%
file5 = 'data/ADV_AllData.csv'
df5 = pd.read_csv(file5)
df5.head()
# Out:
#   Location  Denominator  Prevalence  Lower CI  Upper CI  Year Source
# 0       AZ      45322.0         6.5       5.8       7.3  2000   addm
# 1       GA      43593.0         6.5       5.8       7.3  2000   addm
# 2       MD      21532.0         5.5       4.6       6.6  2000   addm
# 3       NJ      29714.0         9.9       8.9      11.1  2000   addm
# 4       SC      24535.0         6.3       5.4       7.4  2000   addm

# %%
df5 = df5.drop(columns='Source')
df5.head()
# Out:
#   Location  Denominator  Prevalence  Lower CI  Upper CI  Year
# 0       AZ      45322.0         6.5       5.8       7.3  2000
# 1       GA      43593.0         6.5       5.8       7.3  2000
# 2       MD      21532.0         5.5       4.6       6.6  2000
# 3       NJ      29714.0         9.9       8.9      11.1  2000
# 4       SC      24535.0         6.3       5.4       7.4  2000

# %%
test = df5.groupby('Year')
test.head()
# Out:
#      Location  Denominator  Prevalence  Lower CI  Upper CI  Year
# 0          AZ      45322.0         6.5       5.8       7.3  2000
# 1          GA      43593.0         6.5       5.8       7.3  2000
# 2          MD      21532.0         5.5       4.6       6.6  2000
# 3          NJ      29714.0         9.9       8.9      11.1  2000
# 4          SC      24535.0         6.3       5.4       7.4  2000
# ...       ...          ...         ...       ...       ...   ...
# 1777       AK     119090.0        10.6      10.1      11.2  2017
# 1778       AL     671939.0         9.8       9.6      10.0  2017
# 1779       AR     442030.0        10.2       9.9      10.5  2017
# 1780       AZ    1016873.0        11.4      11.2      11.6  2017
# 1781       CA    5679408.0        14.9      14.8      15.0  2017
#
# [100 rows x 6 columns]

# %%
df6 = pd.read_csv('data/Autism_Data.arff')
df6.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ... gender       ethnicity jundice austim  \
# 0         1         0          0  ...      f  White-European      no     no
# 1         1         0          1  ...      m          Latino      no    yes
# 2         1         1          1  ...      m          Latino     yes    yes
# 3         1         0          1  ...      f  White-European      no    yes
# 4         1         0          0  ...      f               ?      no     no
#
#      contry_of_res used_app_before result       age_desc relation Class/ASD
# ...

# %%
df6.count()
# Out:
# A1_Score           704
# A2_Score           704
# A3_Score           704
# A4_Score           704
# A5_Score           704
# A6_Score           704
# A7_Score           704
# A8_Score           704
# A9_Score           704
# A10_Score          704
# age                704
# gender             704
# ethnicity          704
# jundice            704
# austim             704
# contry_of_res      704
# used_app_before    704
# result             704
# age_desc           704
# relation           704
# Class/ASD          704
# dtype: int64

# %%
df6.shape
# Out:
# (704, 21)

# %%
df6.isnull().sum()
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                0
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %%
df6.dtypes
# Out:
# A1_Score            int64
# A2_Score            int64
# A3_Score            int64
# A4_Score            int64
# A5_Score            int64
# A6_Score            int64
# A7_Score            int64
# A8_Score            int64
# A9_Score            int64
# A10_Score           int64
# age                object
# gender             object
# ethnicity          object
# jundice            object
# austim             object
# contry_of_res      object
# used_app_before    object
# result              int64
# age_desc           object
# relation           object
# Class/ASD          object
# dtype: object

# %%
test=df5[['Year','Prevalence']]
test = test.dropna()

# %%
test.isnull().sum()
# Out:
# Year          0
# Prevalence    0
# dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1869 entries, 0 to 1876
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        1869 non-null   int64
#  1   Prevalence  1869 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 43.8 KB

# %%
# Not good
# from sklearn.linear_model import LinearRegression
# import numpy as np
# X = np.array(test['Year']).reshape(-1,1)
# y = np.array(test['Prevalence']).reshape(-1,1)

# %%
# Not good
# from sklearn.metrics import r2_score
# new_model = LinearRegression().fit(X, y)
# # This gives as some results that may be useful
# print(new_model.coef_)
# print(new_model.intercept_)

# # This will predict
# new_model.predict(np.array(test['Year']).reshape(-1,1)) # x column. Shape has to match

# r2_score(y,np.array(test['Year']).reshape(-1,1))
# Out:
# [[0.81126458]]
# [-1621.48164598]
# -104960.38210500777

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(test['Year'], test['Prevalence'], random_state=1)

X_train = np.array(X_train).reshape(-1,1)
X_test = np.array(X_test).reshape(-1,1)
y_train = np.array(y_train).reshape(-1,1)
y_test = np.array(y_test).reshape(-1,1)

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))

# Plot outputs
plt.scatter(X_test, y_test, color="black")
plt.plot(X_test, y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [[0.79080526]]
# Mean squared error: 22.03
# Coefficient of determination: 0.49

# %%
file7 = 'data/2019-2020 NSCH_Topical_CAHMI_DRC.csv'
df7 = pd.read_csv(file7)
df7.head()
# Out:
#    FIPSST  STRATUM      HHID  FORMTYPE  TOTKIDS_R  TENURE  HHLANGUAGE  \
# 0       1        1  19000167         3          2       3           1
# 1       1        1  19001238         1          4       1           1
# 2       1        1  19001344         3          3       1           1
# 3       1        1  19001345         3          1       1           1
# 4       1        1  19001347         1          1       3           1
#
#    SC_AGE_YEARS  SC_SEX  K2Q35A_1_YEARS  ...  npm9bullied_1920  \
# 0            17       1              95  ...                 1
# 1             4       2              95  ...                90
# 2            14       1              95  ...                 2
# 3            16       2              95  ...                 2
# 4             5       2              95  ...                90
#
#    npm9bully_1920  npm10PrVi_1920  npm11MHCSHCN_1920  npm11MHnonCSHCN_1920  \
# 0               1               2                 95                     1
# ...

# %%
df7.nunique()
# Out:
# FIPSST                        51
# STRATUM                        2
# HHID                       72210
# FORMTYPE                       3
# TOTKIDS_R                      4
#                            ...
# npm12TransCSHCN_1920           5
# npm12TransNonCSHCN_1920        5
# npm13_2DePrev_1920             4
# npm14_2Smoke_1920              3
# npm15AdIns_1920                3
# Length: 820, dtype: int64

# %%
file8 = 'data/2019 NSCHTopical_CAHMI DRC.csv'
df8 = pd.read_csv(file8)
df8.head()
# Out:
#    FIPSST  STRATUM      HHID  FORMTYPE  TOTKIDS_R  TENURE  HHLANGUAGE  \
# 0      51        2  19000001         1          1       1           1
# 1      21        1  19000002         3          1       1           1
# 2      13        1  19000003         2          1       1           1
# 3      47        1  19000006         2          3       1           1
# 4      18        1  19000010         1          3       1           1
#
#    SC_AGE_YEARS  SC_SEX  K2Q35A_1_YEARS  ...  npm15AdIns_19  nom14TthDec_19  \
# 0             1       2              95  ...              1               2
# 1            15       1              95  ...              1               2
# 2             6       2              95  ...              1               2
# 3            10       1              95  ...              2               2
# 4             0       2              95  ...              1              95
#
#    nom17_1CSHCN_19  nom17_2sysCSHCN_19  nom17_3ASD_19  nom17_4ADHD_19  \
# ...

# %%
df8.nunique()
# Out:
# FIPSST                  51
# STRATUM                  2
# HHID                 29433
# FORMTYPE                 3
# TOTKIDS_R                4
#                      ...
# nom17_4ADHD_19           5
# nom18MHlth_19            4
# nom19ChHSt_19            4
# nom20obese_19            6
# nom25ForgoneHC_19        3
# Length: 834, dtype: int64
